# %% [markdown]
# # Inference Demo
# Run object detection on local files.

# %%
import cv2
import matplotlib.pyplot as plt
from detectify.inference import InferenceEngine

engine = InferenceEngine().load_model()
print("Model Loaded successfully")
