# %% [markdown]
# # Detectify Exploration
# Explore data and model performance.

# %%
import sys
from pathlib import Path
sys.path.append('../src')

from detectify.model import TFDetector
from detectify.utils import set_seed

set_seed(42)
print("Detectify Ready")
